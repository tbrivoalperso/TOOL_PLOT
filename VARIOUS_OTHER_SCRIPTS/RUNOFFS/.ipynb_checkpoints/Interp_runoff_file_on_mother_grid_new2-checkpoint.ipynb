# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import shutil
from shutil import copyfile

# %%
def check_mask_nearby_ij(i,j,mask,ndist):
    # i = index along i of point to test
    # j = index along j of point to test
    # mask = 2D mask 
    # ndist = distance from center to check
    if (i > (ndist-1)):
        TEST_i = np.nansum(mask[i-ndist:i+ndist+1,j])
    else:
        TEST_i = np.nansum(mask[i:i+ndist+1,j])
    if (j > (ndist-1)):
        TEST_j = np.nansum(mask[i,j-ndist:j+ndist+1])
    else:
        TEST_j = np.nansum(mask[i,j:j+ndist+1])
    return TEST_i, TEST_j

# %%
def check_if_surrounded_by_land(i,j,mask,ndist):
    surrounded_by_land=0
    # i = index along i of point to test
    # j = index along j of point to test
    # mask = 2D mask 
    # ndist = distance from center to check
    if (i > (ndist-1)):
        if (j > (ndist-1)):
            npts = np.nansum(mask[i-ndist:i+ndist+1,j-ndist:j+ndist+1])
            if npts == (1+(ndist*2))**2 :
                surrounded_by_land=1
        else:
            npts = np.nansum(mask[i-ndist:i+ndist+1,j:j+ndist+1])
            if npts == (1+(ndist*2))*(1+(ndist*2)-ndist) :
                surrounded_by_land=1
    else:
        if (j > (ndist-1)):
            TEST = np.nansum(mask[i:i+ndist+1,j-ndist:j+ndist+1])
            if npts == (1+(ndist*2))*(1+(ndist*2)-ndist):
                surrounded_by_land=1
        else:
            TEST = np.nansum(mask[i:i+ndist+1,j:j+ndist+1])
            if npts == (1+(ndist*2)-ndist)*(1+(ndist*2)-ndist) :
                surrounded_by_land=1
    return surrounded_by_land

# %%
def check_if_surrounded_by_sea(i,j,mask,ndist):
    mask_inv=np.where(mask==1,0,1)
    surrounded_by_sea=0
    # i = index along i of point to test
    # j = index along j of point to test
    # mask_inv = 2D mask_inv 
    # ndist = distance from center to check
    if (i > (ndist-1)):
        if (j > (ndist-1)):
            npts = np.nansum(mask_inv[i-ndist:i+ndist+1,j-ndist:j+ndist+1])
            if npts == (1+(ndist*2))**2 :
                surrounded_by_sea=1
        else:
            npts = np.nansum(mask_inv[i-ndist:i+ndist+1,j:j+ndist+1])
            if npts == (1+(ndist*2))*(1+(ndist*2)-ndist) :
                surrounded_by_sea=1
    else:
        if (j > (ndist-1)):
            TEST = np.nansum(mask_inv[i:i+ndist+1,j-ndist:j+ndist+1])
            if npts == (1+(ndist*2))*(1+(ndist*2)-ndist):
                surrounded_by_sea=1
        else:
            TEST = np.nansum(mask_inv[i:i+ndist+1,j:j+ndist+1])
            if npts == (1+(ndist*2)-ndist)*(1+(ndist*2)-ndist) :
                surrounded_by_sea=1
    return surrounded_by_sea

# %%
def find_nearest_sea_point(i,j,mask,ndist,rnf_data):
    i_ind_new=[]
    j_ind_new=[]
    
# First, check along i / j only
    if (i > (ndist-1)):
        if (j > (ndist-1)):
            arr = rnf_data[i-ndist:i+ndist+1,j-ndist:j+ndist+1] + mask[i-ndist:i+ndist+1,j-ndist:j+ndist+1]
        else:
            arr = rnf_data[i-ndist:i+ndist+1,j:j+ndist+1] + mask[i-ndist:i+ndist+1,j:j+ndist+1]
    else:
        if (j > (ndist-1)):
            arr = rnf_data[i:i+ndist+1,j-ndist:j+ndist+1] + mask[i:i+ndist+1,j-ndist:j+ndist+1]
        else:
            arr = rnf_data[i:i+ndist+1,j:j+ndist+1] + mask[i:i+ndist+1,j:j+ndist+1]
   
    available_points_all=np.argwhere(arr[:,:]==0)  - 1
    available_points_all[:,0]=available_points_all[:,0] + i 
    available_points_all[:,1]=available_points_all[:,1] + j     
# First, check if there is an empty point around
    if 0 in arr:
        # check along i and j axis only
        arr_ij=np.ones(arr.shape)
        arr_ij[ndist,:]=arr[ndist,:]
        arr_ij[:,ndist]=arr[:,ndist]
        available_points_ij=np.argwhere(arr_ij[:,:]==0) - 1
        available_points_ij[:,0]=available_points_ij[:,0] + i 
        available_points_ij[:,1]=available_points_ij[:,1] + j 
        if 0 in arr_ij :
            return available_points_ij
        else:
            return available_points_all

    else: # If no empty point, return the closests sea points
        
        if (i > (ndist-1)):
            if (j > (ndist-1)):
                arr = mask[i-ndist:i+ndist+1,j-ndist:j+ndist+1]
            else:
                arr = mask[i-ndist:i+ndist+1,j:j+ndist+1]
        else:
            if (j > (ndist-1)):
                arr = mask[i:i+ndist+1,j-ndist:j+ndist+1]
            else:
                arr = mask[i:i+ndist+1,j:j+ndist+1]  
                
        available_points_all=np.argwhere(arr[:,:]==0)  - 1
        available_points_all[:,0]=available_points_all[:,0] + i 
        available_points_all[:,1]=available_points_all[:,1] + j  
        if 0 in arr:
            arr_ij=np.ones(arr.shape)
            arr_ij[ndist,:]=arr[ndist,:]
            arr_ij[:,ndist]=arr[:,ndist]
            available_points_ij=np.argwhere(arr_ij[:,:]==0)
            available_points_ij[:,0]=available_points_ij[:,0] + i 
            available_points_ij[:,1]=available_points_ij[:,1] + j 
            if 0 in arr_ij :
                return available_points_ij
            else:
                return available_points_all
            del(available_points_all, available_points_ij)
        else:
            print("ERROR")

# %%
def find_nearest_land_point(i,j,mask,ndist,rnf_data):
    mask_inv=np.where(mask==1,0,1)
    i_ind_new=[]
    j_ind_new=[]
    
# First, check along i / j only
    if (i > (ndist-1)):
        if (j > (ndist-1)):
            arr = rnf_data[i-ndist:i+ndist+1,j-ndist:j+ndist+1] + mask_inv[i-ndist:i+ndist+1,j-ndist:j+ndist+1]
        else:
            arr = rnf_data[i-ndist:i+ndist+1,j:j+ndist+1] + mask_inv[i-ndist:i+ndist+1,j:j+ndist+1]
    else:
        if (j > (ndist-1)):
            arr = rnf_data[i:i+ndist+1,j-ndist:j+ndist+1] + mask_inv[i:i+ndist+1,j-ndist:j+ndist+1]
        else:
            arr = rnf_data[i:i+ndist+1,j:j+ndist+1] + mask_inv[i:i+ndist+1,j:j+ndist+1]
   
    available_points_all=np.argwhere(arr[:,:]==0)  - 1
    available_points_all[:,0]=available_points_all[:,0] + i 
    available_points_all[:,1]=available_points_all[:,1] + j     
# First, check if there is an empty point around
    if 0 in arr:
        # check along i and j axis only
        arr_ij=np.ones(arr.shape)
        arr_ij[ndist,:]=arr[ndist,:]
        arr_ij[:,ndist]=arr[:,ndist]
        available_points_ij=np.argwhere(arr_ij[:,:]==0) - 1
        available_points_ij[:,0]=available_points_ij[:,0] + i 
        available_points_ij[:,1]=available_points_ij[:,1] + j 
        if 0 in arr_ij :
            return available_points_ij
        else:
            return available_points_all

    else: # If no empty point, return the closests sea points
        
        if (i > (ndist-1)):
            if (j > (ndist-1)):
                arr = mask_inv[i-ndist:i+ndist+1,j-ndist:j+ndist+1]
            else:
                arr = mask_inv[i-ndist:i+ndist+1,j:j+ndist+1]
        else:
            if (j > (ndist-1)):
                arr = mask_inv[i:i+ndist+1,j-ndist:j+ndist+1]
            else:
                arr = mask_inv[i:i+ndist+1,j:j+ndist+1]  
                
        available_points_all=np.argwhere(arr[:,:]==0)  - 1
        available_points_all[:,0]=available_points_all[:,0] + i 
        available_points_all[:,1]=available_points_all[:,1] + j  
        if 0 in arr:
            arr_ij=np.ones(arr.shape)
            arr_ij[ndist,:]=arr[ndist,:]
            arr_ij[:,ndist]=arr[:,ndist]
            available_points_ij=np.argwhere(arr_ij[:,:]==0)
            available_points_ij[:,0]=available_points_ij[:,0] + i 
            available_points_ij[:,1]=available_points_ij[:,1] + j 
            if 0 in arr_ij :
                return available_points_ij
            else:
                return available_points_all
            del(available_points_all, available_points_ij)
        else:
            print("ERROR")

# %%
def move_runoffs(rnf_2D,rnf_point,mask,lverb):
# --------------------------------------------------------------------------------------------------
# PURPOSE :
# Check runoff data and move data off the coast or over land at the first available point near the coast
# ------------------------------------
# CASE 1 : Runoff point is over land : 
# find the nearest(s) sea point(s) and return its (their) index : ind=(i,j) or ind(i1,j1,i2,j2....)
# 2 possibilities : 
#    => At least one runoff value at ind=(in,jn) is 0.0 : move data over this point
#    => No runoff value at ind=(in,jn) is > 0.0 : add runoff value to this point
# When more than one sea point is found (ind(i1,j1,i2,j2....)), the runoff is averaged over every points
#
# ------------------------------------
# CASE 2 : Runoff point is surrounded by sea : 
# Find the nearest coast point
# If more than one coast points are available, average avor the two coast points
#
#
# --------------------------------------------------------------------------------------------------
# Inputs : 
# rnf_2D = runoff data in 2 dimension
# rnf_point = array with indexes of rnf points (should have the form : (2,N), 
# where N is the number of runoff points)
# mask = output mask (1 over sea points and 0 over land points)
# lverb = verbose (True or False)
# --------------------------------------------------------------------------------------------------
# Output : New 2D array with moved runoffs
# --------------------------------------------------------------------------------------------------

# Initialisation
    nseuil=30 # over 30 points distance, do not replace runoff
    rnf_2D_new = np.copy(rnf_2D)
    mask_data=mask
    mask_data=np.where(mask_data==1,0,1) # invert mask
    sea_point_not_found=0.
    ndist=1
    
# --------------------------------------------------------------------------------------------------
# BEGIN LOOP

# Loop over valid runoff values only  
    for n in range(len(rnf_point[0,:])): 
        N_earth_points_i, N_earth_points_j = check_mask_nearby_ij(rnf_point[0,n],\
                                                               rnf_point[1,n],mask_data,ndist)
        N_earth_points_ij = N_earth_points_i + N_earth_points_j
        
        if (mask_data[rnf_point[0,n],rnf_point[1,n]]==1): # POINT IS OVER LAND ------------
            surrounded = check_if_surrounded_by_land(rnf_point[0,n],\
                                                           rnf_point[1,n],mask_data,ndist)
            if lverb: print("==> j, i = ", rnf_point[0,n],rnf_point[1,n],                    \
                            "is on mask point")

            if surrounded == 1: # Surrounded by earth
                if (ndist > nseuil): 
                    if lverb: print("WARNING !!! : closest sea point is over ",nseuil,"\
                    point perimeter at i, j = ", rnf_point[0,n],rnf_point[1,n])

                while sea_point_not_found == 0:
                    surrounded = check_if_surrounded_by_land(rnf_point[0,n],\
                                                           rnf_point[1,n],mask_data,ndist)

                    if surrounded == 1: # No sea point in ndist perimeter 
                        print(rnf_point[0,n],rnf_point[1,n],\
                                        "surrounded by earth points, trying ndist=+1;",      \
                                        "next radius = ", (1+((ndist+1)*2)))
                    else: # At least one sea point in ndist perimeter
                        sea_point_not_found=1.
                        indexes_closests_sea_point=find_nearest_sea_point(rnf_point[0,n],rnf_point[1,n],          \
                                                     mask_data,ndist,rnf_2D.values)

                    ndist=ndist+1
   
            else: # AT LEAST ONE SEA POINT in ndist=1 perimeter ------------
                indexes_closests_sea_point=find_nearest_sea_point(rnf_point[0,n],rnf_point[1,n],mask_data,        \
                                             ndist,rnf_2D.values)
    # NOW REPLACE RUNOFFS
            npoints=len(indexes_closests_sea_point[:,0])
            print("npoints=",npoints)
            # Now replace data
            if npoints == 0: 
                # No available points nearby without an already existing runoff value => avoid
                rnf_2D_new[rnf_point[0,n],rnf_point[1,n]] = 0.  
                print(rnf_point[0,n],rnf_point[1,n],"ISSUE AT THIS POINT !!")
            else: 
                for ind in range(npoints):
                    rnf_2D_new[int(indexes_closests_sea_point[ind,0]),int(indexes_closests_sea_point[ind,1])] \
                    = rnf_2D_new[int(indexes_closests_sea_point[ind,0]),int(indexes_closests_sea_point[ind,1])]    \
                    + (rnf_2D_new[rnf_point[0,n],rnf_point[1,n]] / npoints) 
                                           if lverb: print("moving point over ", npoints, "points, : i, j =", \
                                        int(indexes_closests_land_point[ind,0]),int(indexes_closests_land_point[ind,1])  ) 
            if lverb: print("..........")

        else: #POINT IS OVER SEA ------------
            ndist=1
            surrounded = check_if_surrounded_by_sea(rnf_point[0,n],\
                                                    rnf_point[1,n],mask_data,ndist)
            # Loop until we find at least one sea point in ndist perimeter$
            if surrounded == 1: # Surrounded by sea
                if lverb: 
                    print("==> j, i = ", rnf_point[0,n],rnf_point[1,n],                    \
                                "is surrounded by sea ")
                if (ndist > nseuil): 
                    print("WARNING !!! : closest land point is over ",nseuil,"\
                    point perimeter at i, j = ", rnf_point[0,n],rnf_point[1,n])

                while sea_point_not_found == 0:
                        surrounded = check_if_surrounded_by_sea(rnf_point[0,n],\
                                                               rnf_point[1,n],mask_data,ndist)
                        
                        if surrounded == 1: # No sea point in ndist perimeter 
                            if lverb: print(rnf_point[0,n],rnf_point[1,n],\
                                            "surrounded by sea points, trying ndist=+1;",      \
                                            "next radius = ", (1+((ndist+1)*2)))
                        else: # At least one sea point in ndist perimeter
                            sea_point_not_found=1.
                            indexes_closests_land_point=find_nearest_land_point(rnf_point[0,n],rnf_point[1,n],          \
                                                         mask_data,ndist,rnf_2D.values)
                      
                        ndist=ndist+1
    # NOW REPLACE RUNOFFS
                npoints=len(indexes_closests_land_point[:,0])
                print("npoints=",npoints)
                # Now replace data
                if npoints == 0: 
                    # No available points nearby without an already existing runoff value => avoid
                    rnf_2D_new[rnf_point[0,n],rnf_point[1,n]] = 0.  
                    print(rnf_point[0,n],rnf_point[1,n],"ISSUE AT THIS POINT !!")
                else: 
                    for ind in range(npoints):
                        rnf_2D_new[int(indexes_closests_land_point[ind,0]),int(indexes_closests_land_point[ind,1])] \
                        = rnf_2D_new[int(indexes_closests_land_point[ind,0]),int(indexes_closests_land_point[ind,1])]    \
                        + (rnf_2D_new[rnf_point[0,n],rnf_point[1,n]] / npoints) 
                        if lverb: print("moving point over ", npoints, "points, : i, j =", \
                                        int(indexes_closests_land_point[ind,0]),int(indexes_closests_land_point[ind,1])  )                                          
                if lverb: print("..........")

        sea_point_not_found=0.
        ndist=1
        # Next point
    return rnf_2D_new
# --------------------------------------------------------------------------------------------------
# END LOOP

# %%
year=2017


rnf_inp_file='/data/vdi/tbrivoal/PRE_PROCESSING_IMMERSE/RUNOFFS_eNEATL36/runoff_eNEATL36_BDY_y'+str(year)+'.nc'
inp_domain_cfg_file='/data/vdi/tbrivoal/PRE_PROCESSING_IMMERSE/RUNOFFS_eNEATL36/DOMAIN_CFG_FINALDOMAIN/domain_cfg_init.nc'
out_runoff_file='/data/vdi/tbrivoal/PRE_PROCESSING_IMMERSE/RUNOFFS_eNEATL36/runoff_eNEATL36_BDY2D_corrected_y'+str(year)+'.nc'
mask_file='/data/vdi/tbrivoal/PRE_PROCESSING_IMMERSE/RUNOFFS_eNEATL36/mesh_mask.nc'
output_folder="/data/vdi/tbrivoal/PRE_PROCESSING_IMMERSE/RUNOFFS_eNEATL36/"

# %%
# Open files
inp_rnf_2D=xr.open_dataset(rnf_inp_file)
inp_domain_cfg=xr.open_dataset(inp_domain_cfg_file,drop_variables={"x", "y",})
maskf=xr.open_dataset(mask_file,drop_variables={"x", "y",})

# %%
# Open variables
# mask_inp =  inp_domain_cfg.top_level.squeeze()
mask_inp =  inp_domain_cfg.top_level.squeeze()

# mask_inp = maskf.tmask[0,0,:,:].squeeze()
rnf_2D=inp_rnf_2D.runoffs_instant.squeeze()
rnf_2D_new=np.copy(rnf_2D)
rnf_point = np.array(np.where(rnf_2D[0,:,:].values>0)) # Assuming runoffs does not move

# %%
for i in range(len(rnf_2D[:,0,0])):
    print(i)
    rnf_2D_new[i,:,:]=move_runoffs(rnf_2D[i,:,:],rnf_point,mask_inp,True)
# Out:
# 0
# ==> j, i =  63 243 is on mask point
# npoints= 2
# ..........
# ==> j, i =  74 254 is on mask point
# npoints= 1
# ..........
# ==> j, i =  76 266 is on mask point
# npoints= 1
# ..........
# ==> j, i =  78 277 is on mask point
# npoints= 1
# ..........
# ==> j, i =  78 278 is on mask point
# npoints= 1
# ..........
# ==> j, i =  79 281 is on mask point
# npoints= 1
# ..........
# ==> j, i =  81 285 is on mask point
# npoints= 1
# ..........
# ==> j, i =  82 287 is on mask point
# npoints= 1
# ..........
# ==> j, i =  82 288 is on mask point
# npoints= 1
# ..........
# ==> j, i =  83 289 is on mask point
# npoints= 2
# ..........
# ==> j, i =  84 291 is on mask point
# npoints= 1
# ..........
# ==> j, i =  84 292 is on mask point
# npoints= 1
# ..........
# ==> j, i =  84 293 is on mask point
# npoints= 1
# ..........
# ==> j, i =  85 294 is on mask point
# npoints= 2
# ..........
# ==> j, i =  86 297 is on mask point
# npoints= 1
# ..........
# ==> j, i =  86 298 is on mask point
# npoints= 1
# ..........
# ==> j, i =  87 299 is on mask point
# npoints= 2
# ..........
# ==> j, i =  87 300 is on mask point
# npoints= 1
# ..........
# ==> j, i =  89 303 is on mask point
# npoints= 1
# ..........
# ==> j, i =  91 305 is on mask point
# npoints= 1
# ..........
# ==> j, i =  93 307 is on mask point
# npoints= 1
# ..........
# ==> j, i =  95 308 is on mask point
# npoints= 1
# ..........
# ==> j, i =  97 310 is on mask point
# npoints= 1
# ..........
# ==> j, i =  99 312 is on mask point
# npoints= 1
# ..........
# ==> j, i =  100 313 is on mask point
# npoints= 1
# ..........
# ==> j, i =  104 317 is on mask point
# npoints= 1
# ..........
# ==> j, i =  107 319 is on mask point
# npoints= 2
# ..........
# ==> j, i =  108 321 is on mask point
# npoints= 1
# ..........
# ==> j, i =  108 322 is on mask point
# npoints= 1
# ..........
# ==> j, i =  110 326 is on mask point
# npoints= 1
# ..........
# ==> j, i =  113 331 is on mask point
# npoints= 1
# ..........
# ==> j, i =  115 333 is on mask point
# npoints= 1
# ..........
# ==> j, i =  115 334 is on mask point
# 115 334 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  116 335 is on mask point
# npoints= 1
# ..........
# ==> j, i =  120 340 is on mask point
# npoints= 2
# ..........
# ==> j, i =  121 341 is on mask point
# npoints= 1
# ..........
# ==> j, i =  124 343 is on mask point
# npoints= 1
# ..........
# ==> j, i =  128 347 is on mask point
# npoints= 1
# ..........
# ==> j, i =  130 349 is on mask point
# npoints= 1
# ..........
# ==> j, i =  136 353 is on mask point
# npoints= 1
# ..........
# ==> j, i =  144 357 is on mask point
# npoints= 1
# ..........
# ==> j, i =  151 363 is on mask point
# npoints= 1
# ..........
# ==> j, i =  170 370 is on mask point
# npoints= 1
# ..........
# ==> j, i =  171 370 is on mask point
# npoints= 1
# ..........
# ==> j, i =  172 370 is on mask point
# npoints= 1
# ..........
# ==> j, i =  173 370 is on mask point
# npoints= 1
# ..........
# ==> j, i =  174 370 is on mask point
# npoints= 1
# ..........
# ==> j, i =  175 370 is on mask point
# npoints= 1
# ..........
# ==> j, i =  196 362 is surrounded by sea
# 196 362 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  197 362 is surrounded by sea
# 197 362 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  228 367 is surrounded by sea
# 228 367 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  229 367 is surrounded by sea
# 229 367 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  230 367 is surrounded by sea
# 230 367 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  242 378 is on mask point
# npoints= 2
# ..........
# ==> j, i =  249 382 is on mask point
# npoints= 1
# ..........
# ==> j, i =  291 405 is on mask point
# npoints= 1
# ..........
# ==> j, i =  310 434 is surrounded by sea
# 310 434 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  314 444 is surrounded by sea
# 314 444 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  349 480 is on mask point
# npoints= 1
# ..........
# ==> j, i =  351 481 is on mask point
# npoints= 1
# ..........
# ==> j, i =  353 482 is on mask point
# npoints= 1
# ..........
# ==> j, i =  359 485 is on mask point
# npoints= 1
# ..........
# ==> j, i =  370 489 is on mask point
# npoints= 1
# ..........
# ==> j, i =  376 491 is on mask point
# npoints= 1
# ..........
# ==> j, i =  382 493 is on mask point
# npoints= 1
# ..........
# ==> j, i =  382 554 is on mask point
# npoints= 1
# ..........
# ==> j, i =  383 549 is on mask point
# npoints= 1
# ..........
# ==> j, i =  383 550 is on mask point
# npoints= 1
# ..........
# ==> j, i =  383 562 is on mask point
# npoints= 1
# ..........
# ==> j, i =  383 627 is surrounded by sea
# 383 627 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  383 628 is surrounded by sea
# 383 628 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  385 543 is on mask point
# npoints= 1
# ..........
# ==> j, i =  385 569 is on mask point
# npoints= 1
# ..........
# ==> j, i =  386 574 is on mask point
# npoints= 2
# ..........
# ==> j, i =  388 539 is on mask point
# npoints= 1
# ..........
# ==> j, i =  389 537 is on mask point
# npoints= 1
# ..........
# ==> j, i =  389 602 is surrounded by sea
# 389 602 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  390 536 is on mask point
# npoints= 2
# ..........
# ==> j, i =  391 535 is on mask point
# npoints= 1
# ..........
# ==> j, i =  391 662 is surrounded by sea
# 391 662 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  393 667 is surrounded by sea
# 393 667 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  393 669 is on mask point
# npoints= 2
# ..........
# ==> j, i =  410 681 is surrounded by sea
# 410 681 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  412 685 is surrounded by sea
# 412 685 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  412 686 is surrounded by sea
# 412 686 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  412 694 is surrounded by sea
# 412 694 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  413 708 is on mask point
# npoints= 1
# ..........
# ==> j, i =  419 717 is on mask point
# npoints= 2
# ..........
# ==> j, i =  420 512 is on mask point
# npoints= 1
# ..........
# ==> j, i =  421 517 is on mask point
# npoints= 1
# ..........
# ==> j, i =  421 518 is on mask point
# npoints= 2
# ..........
# ==> j, i =  422 506 is on mask point
# npoints= 1
# ..........
# ==> j, i =  422 519 is on mask point
# npoints= 2
# ..........
# ==> j, i =  430 726 is on mask point
# npoints= 1
# ..........
# ==> j, i =  436 736 is on mask point
# npoints= 1
# ..........
# ==> j, i =  439 531 is on mask point
# npoints= 1
# ..........
# ==> j, i =  440 534 is on mask point
# npoints= 1
# ..........
# ==> j, i =  441 543 is on mask point
# npoints= 1
# ..........
# ==> j, i =  441 544 is on mask point
# npoints= 1
# ..........
# ==> j, i =  442 487 is on mask point
# npoints= 3
# ..........
# ==> j, i =  442 547 is on mask point
# npoints= 2
# ..........
# ==> j, i =  444 548 is on mask point
# npoints= 1
# ..........
# ==> j, i =  445 549 is on mask point
# npoints= 1
# ..........
# ==> j, i =  446 551 is on mask point
# npoints= 2
# ..........
# ==> j, i =  447 552 is on mask point
# npoints= 2
# ..........
# ==> j, i =  449 553 is on mask point
# npoints= 1
# ..........
# ==> j, i =  449 762 is surrounded by sea
# 449 762 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  449 763 is surrounded by sea
# 449 763 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  449 780 is on mask point
# npoints= 1
# ..........
# ==> j, i =  450 554 is on mask point
# npoints= 1
# ..........
# ==> j, i =  451 792 is on mask point
# npoints= 1
# ..........
# ==> j, i =  452 592 is on mask point
# npoints= 1
# ..........
# ==> j, i =  452 800 is on mask point
# npoints= 1
# ..........
# ==> j, i =  452 802 is surrounded by sea
# 452 802 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  452 803 is surrounded by sea
# 452 803 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  452 804 is surrounded by sea
# 452 804 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  453 570 is on mask point
# npoints= 1
# ..........
# ==> j, i =  453 578 is on mask point
# npoints= 1
# ..........
# ==> j, i =  453 610 is on mask point
# npoints= 1
# ..........
# ==> j, i =  453 798 is on mask point
# npoints= 1
# ..........
# ==> j, i =  454 609 is on mask point
# npoints= 1
# ..........
# ==> j, i =  456 907 is on mask point
# npoints= 1
# ..........
# ==> j, i =  457 483 is on mask point
# npoints= 1
# ..........
# ==> j, i =  457 621 is on mask point
# npoints= 1
# ..........
# ==> j, i =  459 482 is on mask point
# npoints= 1
# ..........
# ==> j, i =  460 431 is surrounded by sea
# 460 431 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 4
# ..........
# ==> j, i =  460 913 is on mask point
# npoints= 1
# ..........
# ==> j, i =  461 392 is surrounded by sea
# 461 392 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  461 393 is surrounded by sea
# 461 393 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  463 390 is surrounded by sea
# 463 390 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  463 435 is surrounded by sea
# 463 435 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  464 390 is surrounded by sea
# 464 390 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  464 846 is on mask point
# npoints= 1
# ..........
# ==> j, i =  465 436 is on mask point
# npoints= 3
# ..........
# ==> j, i =  465 922 is surrounded by sea
# 465 922 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  465 923 is surrounded by sea
# 465 923 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  468 646 is on mask point
# npoints= 1
# ..........
# ==> j, i =  469 468 is on mask point
# npoints= 1
# ..........
# ==> j, i =  472 951 is on mask point
# npoints= 1
# ..........
# ==> j, i =  480 651 is on mask point
# npoints= 1
# ..........
# ==> j, i =  481 652 is on mask point
# npoints= 2
# ..........
# ==> j, i =  486 658 is on mask point
# npoints= 1
# ..........
# ==> j, i =  490 662 is on mask point
# npoints= 2
# ..........
# ==> j, i =  491 663 is on mask point
# npoints= 2
# ..........
# ==> j, i =  492 664 is on mask point
# npoints= 1
# ..........
# ==> j, i =  492 674 is surrounded by sea
# 492 674 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  496 689 is surrounded by sea
# 496 689 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  497 689 is surrounded by sea
# 497 689 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  500 396 is surrounded by sea
# 500 396 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  501 396 is surrounded by sea
# 501 396 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  511 687 is on mask point
# npoints= 1
# ..........
# ==> j, i =  527 384 is on mask point
# npoints= 1
# ..........
# ==> j, i =  534 698 is on mask point
# npoints= 1
# ..........
# ==> j, i =  538 704 is on mask point
# npoints= 1
# ..........
# ==> j, i =  539 373 is on mask point
# npoints= 1
# ..........
# ==> j, i =  562 705 is on mask point
# npoints= 1
# ..........
# ==> j, i =  566 703 is on mask point
# npoints= 1
# ..........
# ==> j, i =  568 376 is on mask point
# npoints= 1
# ..........
# ==> j, i =  572 375 is surrounded by sea
# 572 375 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  572 376 is surrounded by sea
# 572 376 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  579 699 is on mask point
# npoints= 1
# ..........
# ==> j, i =  581 811 is surrounded by sea
# 581 811 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  583 699 is on mask point
# npoints= 2
# ..........
# ==> j, i =  586 699 is on mask point
# npoints= 1
# ..........
# ==> j, i =  588 700 is on mask point
# npoints= 1
# ..........
# ==> j, i =  590 795 is on mask point
# npoints= 2
# ..........
# ==> j, i =  591 701 is on mask point
# npoints= 1
# ..........
# ==> j, i =  592 702 is on mask point
# npoints= 2
# ..........
# ==> j, i =  595 703 is on mask point
# npoints= 1
# ..........
# ==> j, i =  603 707 is on mask point
# npoints= 1
# ..........
# ==> j, i =  604 708 is on mask point
# npoints= 2
# ..........
# ==> j, i =  605 709 is on mask point
# npoints= 2
# ..........
# ==> j, i =  616 393 is on mask point
# npoints= 1
# ..........
# ==> j, i =  631 396 is on mask point
# npoints= 1
# ..........
# ==> j, i =  675 781 is on mask point
# npoints= 1
# ..........
# ==> j, i =  677 784 is on mask point
# npoints= 2
# ..........
# ==> j, i =  680 785 is on mask point
# npoints= 1
# ..........
# ==> j, i =  691 798 is on mask point
# npoints= 1
# ..........
# ==> j, i =  692 800 is on mask point
# npoints= 1
# ..........
# ==> j, i =  693 802 is on mask point
# npoints= 1
# ..........
# ==> j, i =  713 820 is on mask point
# npoints= 2
# ..........
# ==> j, i =  716 388 is surrounded by sea
# 716 388 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  717 821 is surrounded by sea
# 717 821 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  721 382 is surrounded by sea
# 721 382 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  723 380 is surrounded by sea
# 723 380 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  726 390 is on mask point
# npoints= 1
# ..........
# ==> j, i =  726 817 is on mask point
# npoints= 1
# ..........
# ==> j, i =  731 381 is on mask point
# npoints= 2
# ..........
# ==> j, i =  737 378 is on mask point
# npoints= 1
# ..........
# ==> j, i =  742 813 is on mask point
# npoints= 1
# ..........
# ==> j, i =  761 387 is surrounded by sea
# 761 387 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  761 397 is surrounded by sea
# 761 397 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  761 398 is surrounded by sea
# 761 398 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  762 389 is surrounded by sea
# 762 389 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  764 405 is surrounded by sea
# 764 405 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  770 537 is on mask point
# npoints= 1
# ..........
# ==> j, i =  771 541 is surrounded by sea
# 771 541 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  771 542 is surrounded by sea
# 771 542 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  771 543 is surrounded by sea
# 771 543 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  772 922 is on mask point
# npoints= 2
# ..........
# ==> j, i =  773 919 is surrounded by sea
# 773 919 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  774 518 is surrounded by sea
# 774 518 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  774 582 is surrounded by sea
# 774 582 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  774 583 is surrounded by sea
# 774 583 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  774 909 is on mask point
# npoints= 2
# ..........
# ==> j, i =  775 444 is on mask point
# npoints= 1
# ..........
# ==> j, i =  775 450 is surrounded by sea
# 775 450 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  775 451 is surrounded by sea
# 775 451 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  775 608 is surrounded by sea
# 775 608 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  775 918 is on mask point
# npoints= 2
# ..........
# ==> j, i =  776 563 is surrounded by sea
# 776 563 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  776 564 is surrounded by sea
# 776 564 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  777 502 is surrounded by sea
# 777 502 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  777 503 is surrounded by sea
# 777 503 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  777 504 is surrounded by sea
# 777 504 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  777 505 is surrounded by sea
# 777 505 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  777 506 is surrounded by sea
# 777 506 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  778 480 is surrounded by sea
# 778 480 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  778 481 is surrounded by sea
# 778 481 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  778 821 is on mask point
# npoints= 1
# ..........
# ==> j, i =  779 440 is on mask point
# npoints= 1
# ..........
# ==> j, i =  779 901 is on mask point
# npoints= 2
# ..........
# ==> j, i =  779 930 is on mask point
# npoints= 1
# ..........
# ==> j, i =  780 438 is on mask point
# npoints= 1
# ..........
# ==> j, i =  780 899 is on mask point
# npoints= 1
# ..........
# ==> j, i =  780 933 is on mask point
# npoints= 1
# ..........
# ==> j, i =  780 934 is on mask point
# npoints= 1
# ..........
# ==> j, i =  784 649 is on mask point
# npoints= 1
# ..........
# ==> j, i =  784 892 is on mask point
# npoints= 2
# ..........
# ==> j, i =  786 834 is on mask point
# npoints= 2
# ..........
# ==> j, i =  786 870 is on mask point
# npoints= 1
# ..........
# ==> j, i =  786 871 is on mask point
# npoints= 1
# ..........
# ==> j, i =  786 872 is on mask point
# npoints= 1
# ..........
# ==> j, i =  786 873 is on mask point
# npoints= 1
# ..........
# ==> j, i =  786 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  786 888 is on mask point
# npoints= 1
# ..........
# ==> j, i =  787 835 is on mask point
# npoints= 1
# ..........
# ==> j, i =  787 877 is surrounded by sea
# 787 877 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  787 890 is on mask point
# npoints= 1
# ..........
# ==> j, i =  787 892 is on mask point
# npoints= 1
# ..........
# ==> j, i =  788 865 is on mask point
# npoints= 1
# ..........
# ==> j, i =  788 878 is surrounded by sea
# 788 878 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  789 877 is surrounded by sea
# 789 877 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  790 865 is on mask point
# npoints= 1
# ..........
# ==> j, i =  791 851 is on mask point
# npoints= 1
# ..........
# ==> j, i =  792 849 is on mask point
# npoints= 2
# ..........
# ==> j, i =  794 843 is on mask point
# npoints= 1
# ..........
# ==> j, i =  795 845 is on mask point
# npoints= 1
# ..........
# ==> j, i =  795 847 is on mask point
# npoints= 1
# ..........
# ==> j, i =  800 652 is on mask point
# npoints= 1
# ..........
# ==> j, i =  800 951 is surrounded by sea
# 800 951 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  802 950 is on mask point
# npoints= 1
# ..........
# ==> j, i =  802 951 is on mask point
# npoints= 1
# ..........
# ==> j, i =  803 953 is on mask point
# npoints= 1
# ..........
# ==> j, i =  807 653 is on mask point
# npoints= 1
# ..........
# ==> j, i =  808 956 is on mask point
# npoints= 1
# ..........
# ==> j, i =  808 958 is on mask point
# npoints= 2
# ..........
# ==> j, i =  814 967 is on mask point
# npoints= 2
# ..........
# ==> j, i =  816 969 is on mask point
# npoints= 1
# ..........
# ==> j, i =  818 977 is on mask point
# npoints= 1
# ..........
# ==> j, i =  820 981 is on mask point
# npoints= 1
# ..........
# ==> j, i =  820 982 is on mask point
# npoints= 1
# ..........
# ==> j, i =  821 984 is on mask point
# npoints= 1
# ..........
# ==> j, i =  855 655 is on mask point
# npoints= 1
# ..........
# ==> j, i =  865 673 is on mask point
# 865 673 surrounded by earth points, trying ndist=+1; next radius =  5
# 865 673 surrounded by earth points, trying ndist=+1; next radius =  7
# 865 673 surrounded by earth points, trying ndist=+1; next radius =  9
# 865 673 surrounded by earth points, trying ndist=+1; next radius =  11
# npoints= 1
# ..........
# ==> j, i =  866 673 is on mask point
# 866 673 surrounded by earth points, trying ndist=+1; next radius =  5
# 866 673 surrounded by earth points, trying ndist=+1; next radius =  7
# 866 673 surrounded by earth points, trying ndist=+1; next radius =  9
# npoints= 1
# ..........
# ==> j, i =  867 672 is on mask point
# 867 672 surrounded by earth points, trying ndist=+1; next radius =  5
# 867 672 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  867 673 is on mask point
# 867 673 surrounded by earth points, trying ndist=+1; next radius =  5
# 867 673 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  868 672 is on mask point
# 868 672 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  868 673 is on mask point
# 868 673 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  869 671 is on mask point
# npoints= 1
# ..........
# ==> j, i =  869 673 is on mask point
# npoints= 1
# ..........
# ==> j, i =  870 671 is on mask point
# npoints= 1
# ..........
# ==> j, i =  873 672 is on mask point
# npoints= 1
# ..........
# ==> j, i =  876 671 is on mask point
# npoints= 1
# ..........
# ==> j, i =  877 671 is on mask point
# npoints= 1
# ..........
# ==> j, i =  883 668 is on mask point
# npoints= 1
# ..........
# ==> j, i =  884 667 is on mask point
# npoints= 2
# ..........
# ==> j, i =  885 666 is on mask point
# npoints= 1
# ..........
# ==> j, i =  893 652 is on mask point
# npoints= 2
# ..........
# ==> j, i =  904 654 is surrounded by sea
# 904 654 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  905 648 is on mask point
# npoints= 1
# ..........
# ==> j, i =  905 652 is on mask point
# npoints= 1
# ..........
# ==> j, i =  908 651 is on mask point
# npoints= 1
# ..........
# ==> j, i =  911 655 is surrounded by sea
# 911 655 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  913 645 is surrounded by sea
# 913 645 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  925 648 is on mask point
# npoints= 1
# ..........
# ==> j, i =  925 649 is on mask point
# npoints= 1
# ..........
# ==> j, i =  925 653 is surrounded by sea
# 925 653 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  926 652 is surrounded by sea
# 926 652 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  926 653 is surrounded by sea
# 926 653 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  927 646 is on mask point
# npoints= 1
# ..........
# ==> j, i =  931 635 is on mask point
# npoints= 1
# ..........
# ==> j, i =  932 633 is on mask point
# npoints= 1
# ..........
# ==> j, i =  945 622 is on mask point
# npoints= 2
# ..........
# ==> j, i =  949 618 is on mask point
# npoints= 1
# ..........
# ==> j, i =  958 615 is on mask point
# npoints= 2
# ..........
# ==> j, i =  959 610 is on mask point
# npoints= 1
# ..........
# ==> j, i =  966 615 is on mask point
# npoints= 1
# ..........
# ==> j, i =  967 611 is on mask point
# npoints= 2
# ..........
# ==> j, i =  972 612 is surrounded by sea
# 972 612 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  975 600 is on mask point
# npoints= 3
# ..........
# ==> j, i =  976 614 is on mask point
# npoints= 2
# ..........
# ==> j, i =  976 617 is on mask point
# npoints= 1
# ..........
# ==> j, i =  983 602 is on mask point
# npoints= 2
# ..........
# ==> j, i =  985 592 is on mask point
# npoints= 1
# ..........
# ==> j, i =  987 586 is on mask point
# npoints= 1
# ..........
# ==> j, i =  994 566 is on mask point
# npoints= 2
# ..........
# ==> j, i =  997 562 is on mask point
# npoints= 1
# ..........
# ==> j, i =  998 556 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1007 527 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1010 520 is surrounded by sea
# 1010 520 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  1011 521 is surrounded by sea
# 1011 521 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  1013 528 is surrounded by sea
# 1013 528 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1016 536 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1019 531 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1023 524 is surrounded by sea
# 1023 524 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1025 532 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1030 516 is surrounded by sea
# 1030 516 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1033 516 is surrounded by sea
# 1033 516 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1034 516 is surrounded by sea
# 1034 516 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1037 520 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1047 584 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1047 608 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1048 552 is surrounded by sea
# 1048 552 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1048 553 is surrounded by sea
# 1048 553 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1048 600 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1048 609 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1048 610 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1048 624 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1049 581 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1049 582 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1049 603 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1049 612 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1050 602 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1052 557 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1052 580 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1052 632 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1053 577 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1054 577 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1055 566 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1056 577 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1057 569 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1057 570 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1060 627 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1069 626 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1091 639 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1091 640 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1093 663 is surrounded by sea
# 1093 663 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1093 664 is surrounded by sea
# 1093 664 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1093 665 is surrounded by sea
# 1093 665 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1098 684 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1099 685 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1101 683 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1109 496 is surrounded by sea
# 1109 496 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1117 500 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1118 486 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1122 482 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1126 489 is surrounded by sea
# 1126 489 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1126 508 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1128 546 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1130 510 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1132 535 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1133 532 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1135 497 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1137 552 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1143 551 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1143 552 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1147 552 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1149 727 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1150 728 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1151 727 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1151 728 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1153 558 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1153 587 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1156 588 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1158 513 is surrounded by sea
# 1158 513 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1159 513 is surrounded by sea
# 1159 513 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1160 513 is surrounded by sea
# 1160 513 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1163 614 is surrounded by sea
# 1163 614 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1168 513 is surrounded by sea
# 1168 513 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1169 513 is surrounded by sea
# 1169 513 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1170 635 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1170 636 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1172 650 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1173 680 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1174 658 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1174 662 is surrounded by sea
# 1174 662 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1174 672 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1175 667 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1177 331 is surrounded by sea
# 1177 331 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1177 332 is surrounded by sea
# 1177 332 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1177 333 is surrounded by sea
# 1177 333 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1178 330 is surrounded by sea
# 1178 330 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  1178 684 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1180 340 is surrounded by sea
# 1180 340 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1180 341 is surrounded by sea
# 1180 341 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 4
# ..........
# ==> j, i =  1180 523 is surrounded by sea
# 1180 523 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1181 348 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1181 523 is surrounded by sea
# 1181 523 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1183 330 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1183 725 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1185 316 is surrounded by sea
# 1185 316 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1187 328 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1188 369 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1192 322 is surrounded by sea
# 1192 322 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1194 375 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1194 376 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1194 377 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1194 565 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1194 705 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1195 316 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1196 557 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1196 741 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1197 743 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1198 744 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1199 714 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1201 519 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1201 529 is surrounded by sea
# 1201 529 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1201 530 is surrounded by sea
# 1201 530 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1201 716 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1202 387 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1202 498 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1202 531 is surrounded by sea
# 1202 531 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1202 570 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1203 531 is surrounded by sea
# 1203 531 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1203 572 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1204 503 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1204 716 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1206 392 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1206 521 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1206 522 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1206 523 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1207 395 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1207 505 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1207 519 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1208 395 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1209 484 is surrounded by sea
# 1209 484 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1209 485 is surrounded by sea
# 1209 485 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  1209 486 is surrounded by sea
# 1209 486 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1210 512 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1211 401 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1211 489 is surrounded by sea
# 1211 489 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1213 403 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1215 323 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1217 406 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1217 482 is surrounded by sea
# 1217 482 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1219 486 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1220 406 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1220 488 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1221 408 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1221 489 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1221 695 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1221 776 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1221 777 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1222 421 is surrounded by sea
# 1222 421 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1223 415 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1223 416 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1223 417 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1224 424 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1226 698 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1226 802 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1227 794 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1227 805 is on mask point
# 1227 805 surrounded by earth points, trying ndist=+1; next radius =  5
# 1227 805 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 2
# ..........
# ==> j, i =  1227 806 is on mask point
# 1227 806 surrounded by earth points, trying ndist=+1; next radius =  5
# 1227 806 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  1227 807 is on mask point
# 1227 807 surrounded by earth points, trying ndist=+1; next radius =  5
# 1227 807 surrounded by earth points, trying ndist=+1; next radius =  7
# 1227 807 surrounded by earth points, trying ndist=+1; next radius =  9
# npoints= 1
# ..........
# ==> j, i =  1227 808 is on mask point
# 1227 808 surrounded by earth points, trying ndist=+1; next radius =  5
# 1227 808 surrounded by earth points, trying ndist=+1; next radius =  7
# 1227 808 surrounded by earth points, trying ndist=+1; next radius =  9
# npoints= 1
# ..........
# ==> j, i =  1227 809 is on mask point
# 1227 809 surrounded by earth points, trying ndist=+1; next radius =  5
# 1227 809 surrounded by earth points, trying ndist=+1; next radius =  7
# 1227 809 surrounded by earth points, trying ndist=+1; next radius =  9
# npoints= 2
# ..........
# ==> j, i =  1228 445 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1228 788 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1228 789 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1228 790 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1228 801 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1228 803 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1228 804 is on mask point
# 1228 804 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1228 806 is on mask point
# 1228 806 surrounded by earth points, trying ndist=+1; next radius =  5
# 1228 806 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 3
# ..........
# ==> j, i =  1228 807 is on mask point
# 1228 807 surrounded by earth points, trying ndist=+1; next radius =  5
# 1228 807 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  1228 808 is on mask point
# 1228 808 surrounded by earth points, trying ndist=+1; next radius =  5
# 1228 808 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  1228 809 is on mask point
# 1228 809 surrounded by earth points, trying ndist=+1; next radius =  5
# 1228 809 surrounded by earth points, trying ndist=+1; next radius =  7
# npoints= 2
# ..........
# ==> j, i =  1229 433 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1229 434 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1229 435 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1229 805 is on mask point
# 1229 805 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1230 697 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1230 804 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1231 697 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1231 809 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1231 810 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1231 811 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1232 697 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1232 783 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1232 812 is on mask point
# 1232 812 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1233 812 is on mask point
# 1233 812 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1234 812 is on mask point
# 1234 812 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1235 702 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1235 808 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1235 809 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1235 810 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1235 811 is on mask point
# 1235 811 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  1236 445 is surrounded by sea
# 1236 445 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 4
# ..........
# ==> j, i =  1241 792 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1242 445 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1243 334 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1244 446 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1246 447 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1248 448 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1250 449 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1250 520 is surrounded by sea
# 1250 520 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1253 802 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1253 803 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1258 800 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1259 339 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1259 799 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1260 799 is on mask point
# 1260 799 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1261 799 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1262 802 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1262 803 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1262 804 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1262 805 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1265 495 is surrounded by sea
# 1265 495 surrounded by sea points, trying ndist=+1; next radius =  5
# 1265 495 surrounded by sea points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  1266 494 is surrounded by sea
# 1266 494 surrounded by sea points, trying ndist=+1; next radius =  5
# 1266 494 surrounded by sea points, trying ndist=+1; next radius =  7
# npoints= 3
# ..........
# ==> j, i =  1266 496 is surrounded by sea
# 1266 496 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1267 494 is surrounded by sea
# 1267 494 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1267 520 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1268 519 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1269 500 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1272 453 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1276 324 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1276 350 is surrounded by sea
# 1276 350 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 5
# ..........
# ==> j, i =  1277 350 is surrounded by sea
# 1277 350 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1278 323 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1278 350 is surrounded by sea
# 1278 350 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1279 325 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1279 504 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1282 318 is surrounded by sea
# 1282 318 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1284 310 is surrounded by sea
# 1284 310 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  1284 314 is surrounded by sea
# 1284 314 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1285 309 is surrounded by sea
# 1285 309 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1286 309 is surrounded by sea
# 1286 309 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1288 448 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1290 308 is surrounded by sea
# 1290 308 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1290 309 is surrounded by sea
# 1290 309 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1291 667 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1292 445 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1294 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1296 516 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1297 518 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1297 658 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1299 317 is surrounded by sea
# 1299 317 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1301 660 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1302 529 is surrounded by sea
# 1302 529 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1302 530 is surrounded by sea
# 1302 530 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1302 531 is surrounded by sea
# 1302 531 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1304 543 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1304 544 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1304 683 is surrounded by sea
# 1304 683 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1304 684 is surrounded by sea
# 1304 684 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1305 508 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1305 542 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1305 547 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1305 663 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1305 688 is surrounded by sea
# 1305 688 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 4
# ..........
# ==> j, i =  1306 541 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1306 546 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1306 664 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1307 665 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1308 445 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1308 544 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1308 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1309 545 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1309 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1310 315 is surrounded by sea
# 1310 315 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1310 443 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1310 546 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1310 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1311 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1312 322 is surrounded by sea
# 1312 322 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1312 323 is surrounded by sea
# 1312 323 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1314 665 is on mask point
# ...
# npoints= 3
# ..........
# ==> j, i =  1236 445 is surrounded by sea
# 1236 445 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 4
# ..........
# ==> j, i =  1241 792 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1242 445 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1243 334 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1244 446 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1246 447 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1248 448 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1250 449 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1250 520 is surrounded by sea
# 1250 520 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1253 802 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1253 803 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1258 800 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1259 339 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1259 799 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1260 799 is on mask point
# 1260 799 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1261 799 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1262 802 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1262 803 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1262 804 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1262 805 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1265 495 is surrounded by sea
# 1265 495 surrounded by sea points, trying ndist=+1; next radius =  5
# 1265 495 surrounded by sea points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  1266 494 is surrounded by sea
# 1266 494 surrounded by sea points, trying ndist=+1; next radius =  5
# 1266 494 surrounded by sea points, trying ndist=+1; next radius =  7
# npoints= 3
# ..........
# ==> j, i =  1266 496 is surrounded by sea
# 1266 496 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1267 494 is surrounded by sea
# 1267 494 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1267 520 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1268 519 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1269 500 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1272 453 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1276 324 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1276 350 is surrounded by sea
# 1276 350 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 5
# ..........
# ==> j, i =  1277 350 is surrounded by sea
# 1277 350 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1278 323 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1278 350 is surrounded by sea
# 1278 350 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1279 325 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1279 504 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1282 318 is surrounded by sea
# 1282 318 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1284 310 is surrounded by sea
# 1284 310 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 3
# ..........
# ==> j, i =  1284 314 is surrounded by sea
# 1284 314 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1285 309 is surrounded by sea
# 1285 309 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1286 309 is surrounded by sea
# 1286 309 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1288 448 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1290 308 is surrounded by sea
# 1290 308 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1290 309 is surrounded by sea
# 1290 309 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1291 667 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1292 445 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1294 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1296 516 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1297 518 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1297 658 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1299 317 is surrounded by sea
# 1299 317 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1301 660 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1302 529 is surrounded by sea
# 1302 529 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1302 530 is surrounded by sea
# 1302 530 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1302 531 is surrounded by sea
# 1302 531 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1304 543 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1304 544 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1304 683 is surrounded by sea
# 1304 683 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1304 684 is surrounded by sea
# 1304 684 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1305 508 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1305 542 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1305 547 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1305 663 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1305 688 is surrounded by sea
# 1305 688 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 4
# ..........
# ==> j, i =  1306 541 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1306 546 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1306 664 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1307 665 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1308 445 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1308 544 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1308 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1309 545 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1309 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1310 315 is surrounded by sea
# 1310 315 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1310 443 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1310 546 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1310 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1311 814 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1312 322 is surrounded by sea
# 1312 322 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1312 323 is surrounded by sea
# 1312 323 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1314 665 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1316 306 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1316 310 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1317 306 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1317 664 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1320 830 is surrounded by sea
# 1320 830 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1320 831 is surrounded by sea
# 1320 831 surrounded by sea points, trying ndist=+1; next radius =  5
# 1320 831 surrounded by sea points, trying ndist=+1; next radius =  7
# npoints= 4
# ..........
# ==> j, i =  1321 822 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1321 832 is surrounded by sea
# 1321 832 surrounded by sea points, trying ndist=+1; next radius =  5
# 1321 832 surrounded by sea points, trying ndist=+1; next radius =  7
# 1321 832 surrounded by sea points, trying ndist=+1; next radius =  9
# npoints= 4
# ..........
# ==> j, i =  1321 833 is surrounded by sea
# 1321 833 surrounded by sea points, trying ndist=+1; next radius =  5
# 1321 833 surrounded by sea points, trying ndist=+1; next radius =  7
# 1321 833 surrounded by sea points, trying ndist=+1; next radius =  9
# npoints= 3
# ..........
# ==> j, i =  1322 661 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1322 834 is surrounded by sea
# 1322 834 surrounded by sea points, trying ndist=+1; next radius =  5
# 1322 834 surrounded by sea points, trying ndist=+1; next radius =  7
# npoints= 1
# ..........
# ==> j, i =  1322 835 is surrounded by sea
# 1322 835 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1323 826 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1324 660 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1325 837 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1326 837 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1327 658 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1327 837 is on mask point
# 1327 837 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1328 837 is on mask point
# 1328 837 surrounded by earth points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1329 836 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1330 836 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1331 836 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1332 836 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1333 340 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1333 444 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1333 834 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1334 339 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1336 315 is surrounded by sea
# 1336 315 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1336 338 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1337 315 is surrounded by sea
# 1337 315 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1338 320 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1338 323 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1339 344 is surrounded by sea
# 1339 344 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1340 356 is surrounded by sea
# 1340 356 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1340 357 is surrounded by sea
# 1340 357 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1340 642 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1341 638 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1342 354 is surrounded by sea
# 1342 354 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1342 549 is surrounded by sea
# 1342 549 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1342 550 is surrounded by sea
# 1342 550 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1346 457 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1346 839 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1347 839 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1348 840 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1349 841 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1350 842 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1350 843 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1351 643 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1353 367 is surrounded by sea
# 1353 367 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1353 642 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1353 846 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1354 362 is surrounded by sea
# 1354 362 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1354 847 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1355 550 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1355 641 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1355 848 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1356 354 is surrounded by sea
# 1356 354 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1356 355 is surrounded by sea
# 1356 355 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 1
# ..........
# ==> j, i =  1356 850 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1357 361 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1358 367 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1359 857 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1359 858 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1361 866 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1361 885 is surrounded by sea
# 1361 885 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1362 869 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1363 871 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1363 872 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1363 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1364 643 is on mask point
# npoints= 3
# ..........
# ==> j, i =  1364 873 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1364 874 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1364 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1365 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1366 877 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1366 878 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1366 879 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1366 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1367 355 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1367 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1368 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1369 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1370 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1371 359 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1371 451 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1371 454 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1371 480 is surrounded by sea
# 1371 480 surrounded by sea points, trying ndist=+1; next radius =  5
# npoints= 2
# ..........
# ==> j, i =  1371 887 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1372 888 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1372 889 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1373 480 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1373 889 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1373 929 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1374 888 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1374 926 is on mask point
# npoints= 2
# ..........
# ==> j, i =  1375 888 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1375 922 is on mask point
# npoints= 1
# ..........
# ==> j, i =  1375 923 is on mask point
# npoints= 1
# ..........
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-6784fdc266da> in <module>
#       1 for i in range(len(rnf_2D[:,0,0])):
#       2     print(i)
# ----> 3     rnf_2D_new[i,:,:]=move_runoffs(rnf_2D[i,:,:],rnf_point,mask_inp,True)
#
# <ipython-input-7-61cfca85f99b> in move_runoffs(rnf_2D, rnf_point, mask, lverb)
#      92         else: #POINT IS OVER SEA ------------
#      93             ndist=1
# ---> 94             surrounded = check_if_surrounded_by_sea(rnf_point[0,n],\
#      95                                                     rnf_point[1,n],mask_data,ndist)
#      96             # Loop until we find at least one sea point in ndist perimeter$
#
# <ipython-input-4-96625561986f> in check_if_surrounded_by_sea(i, j, mask, ndist)
#       1 def check_if_surrounded_by_sea(i,j,mask,ndist):
# ----> 2     mask_inv=np.where(mask==1,0,1)
#       3     surrounded_by_sea=0
#       4     # i = index along i of point to test
#       5     # j = index along j of point to test
#
# KeyboardInterrupt:

# %%
year=2017 # year of runoff file

# Date variables ----------------------------------------------------------------------------------------
dstart_year= str(year) + "-01-01" # 1st day of the year
dend_year= str(year) + "-12-31" # last day of the year

dstart_clim_monthly = str(year) + "-01-15" # for 12 month clim
dend_clim_monthly = str(year) + "-12-15" # for 12 month clim
dstart_minus_1_month = str(year-1) + "-12-01" # used for conversion from monthly to daily clim data

############################ Save in a Netcdf ###################################
time_counter_daily = pd.date_range(dstart_year,dend_year, freq="D") # time dimension

# time_counter_daily_float = pd.to_numeric(time_counter_daily, downcast='float')
#time_counter_daily.values.astype("float")
# Create xarray dataarray
rnf_2D_daily_new_da = xr.DataArray(
    data=rnf_2D_new,
    dims=["time_counter", "y", "x"],
    coords=dict(time_counter=time_counter_daily.values),
    attrs=rnf_2D.attrs,
    name=rnf_2D.name,
     )



# Create dataset
ds = xr.merge([rnf_2D_daily_new_da, inp_rnf_2D.nav_lat, inp_rnf_2D.nav_lon])
ds.attrs=inp_rnf_2D.attrs
# Save to netcdf
outfile =   out_domain_cfg_file
# outfile = output_folder + "runoff_eNEATL36_with_BDY_y" + str(year) + '.nc'  

ds.to_netcdf(outfile, mode="w")

# %%
print(np.nansum(rnf_2D_new[:,:,:]) - np.nansum(inp_rnf_2D.runoffs_instant.squeeze()))
